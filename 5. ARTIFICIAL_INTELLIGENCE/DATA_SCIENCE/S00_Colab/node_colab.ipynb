# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %%
# !git clone https://github.com/aerovfx/Stable-Diffusion-Graph-node-ComfyUI
# %cd Stable-Diffusion-Graph-node-ComfyUI
# !pip install -r requirements.txt
# Out:
# Cloning into 'Stable-Diffusion-Graph-node-ComfyUI'...
# remote: Enumerating objects: 773, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 773 (delta 134), reused 156 (delta 117), pack-reused 592
# Receiving objects: 100% (773/773), 1.44 MiB | 1.54 MiB/s, done.
# Resolving deltas: 100% (432/432), done.
# /content/Stable-Diffusion-Graph-node-ComfyUI
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 1)) (1.13.1+cu116)
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting torchsde
#   Downloading torchsde-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 7.6 MB/s eta 0:00:00
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 11.2 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 5.0 MB/s eta 0:00:00
# Collecting open-clip-torch
#   Downloading open_clip_torch-2.14.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.8 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 75.4 MB/s eta 0:00:00
# Collecting safetensors
#   Downloading safetensors-0.2.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.9 MB/s eta 0:00:00
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-1.9.3-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.4/826.4 KB 67.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 10)) (3.8.4)
# Collecting accelerate
#   Downloading accelerate-0.16.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from torchdiffeq->-r requirements.txt (line 2)) (1.7.3)
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Collecting boltons>=20.2.1
#   Downloading boltons-23.0.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.* in /usr/local/lib/python3.8/dist-packages (from torchsde->-r requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.8/dist-packages (from omegaconf->-r requirements.txt (line 4)) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 25.1 MB/s eta 0:00:00
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.9 MB/s eta 0:00:00
# Collecting timm
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from open-clip-torch->-r requirements.txt (line 6)) (0.14.1+cu116)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.3 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from open-clip-torch->-r requirements.txt (line 6)) (4.64.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from open-clip-torch->-r requirements.txt (line 6)) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers->-r requirements.txt (line 7)) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers->-r requirements.txt (line 7)) (2.25.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 103.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers->-r requirements.txt (line 7)) (3.9.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning->-r requirements.txt (line 9)) (2023.1.0)
# Collecting lightning-utilities>=0.6.0.post0
#   Downloading lightning_utilities-0.7.1-py3-none-any.whl (18 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.1-py3-none-any.whl (517 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 48.3 MB/s eta 0:00:00
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (3.0.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate->-r requirements.txt (line 11)) (5.4.8)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp->-r requirements.txt (line 10)) (2.10)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->open-clip-torch->-r requirements.txt (line 6)) (0.2.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->-r requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers->-r requirements.txt (line 7)) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->open-clip-torch->-r requirements.txt (line 6)) (7.1.2)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=f39a54ca0c21f66da16ddead2181f145a04881417d281e0aa7333c54494965c1
#   Stored in directory: /root/.cache/pip/wheels/b1/a3/c2/6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
# Successfully built antlr4-python3-runtime
# Installing collected packages: trampoline, tokenizers, sentencepiece, safetensors, boltons, antlr4-python3-runtime, protobuf, omegaconf, lightning-utilities, ftfy, einops, torchsde, torchmetrics, torchdiffeq, huggingface-hub, accelerate, transformers, timm, pytorch_lightning, open-clip-torch
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed accelerate-0.16.0 antlr4-python3-runtime-4.9.3 boltons-23.0.0 einops-0.6.0 ftfy-6.1.1 huggingface-hub-0.12.1 lightning-utilities-0.7.1 omegaconf-2.3.0 open-clip-torch-2.14.0 protobuf-3.20.3 pytorch_lightning-1.9.3 safetensors-0.2.8 sentencepiece-0.1.97 timm-0.6.12 tokenizers-0.13.2 torchdiffeq-0.2.3 torchmetrics-0.11.1 torchsde-0.2.5 trampoline-0.1.2 transformers-4.26.1

# %% [markdown]
# Download some models/checkpoints/vae:

# %%
# !wget https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -P ./models/checkpoints/
# !wget https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -P ./models/vae/
# !wget https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors -P ./models/checkpoints/
# Out:
# --2023-02-23 21:53:48--  https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt
# Resolving huggingface.co (huggingface.co)... 3.231.67.228, 54.235.118.239, 2600:1f18:147f:e850:e203:c458:10cd:fc3c, ...
# Connecting to huggingface.co (huggingface.co)|3.231.67.228|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/6b/20/6b201da5f0f5c60524535ebb7deac2eef68605655d3bbacfee9cce0087f3b3f5/cc6cb27103417325ff94f52b7a5d2dde45a7515b25c255d8e396c90014281516?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27v1-5-pruned-emaonly.ckpt%3B+filename%3D%22v1-5-pruned-emaonly.ckpt%22%3B&Expires=1677445971&Policy=__&Signature=sq-ArxUmBD-ivE935Xavn2qnXfC0JHVHNffnJ4RSdEtRUCXEzyCj7NkzE%7EYpMgBKOtA9Tyza4I6oU-o6gj75oBjLPgF6SNAaQcYj8q6yH87uaePWBXvskIXNSZ2HOVjWLaLB%7EIkiVkEi%7ETkBqOnIbwLlBOfdKOPS4FLT-oEJNU6xgAlxKWIWj8ttJtCP8pK6Vmk6A2f0eMDuD6fZY8Ha-cDsdoVhl0It43szRSraK8JaA-bLTkOOoaWE62jYkbeNKWO40k9k6FttXfk-cdBS7JbWLPocs7colqVORnIPpb29nEnfQ86O9hwLj4AXH91gx%7EmK4beA3OtljGlytbckqQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-02-23 21:53:49--  https://cdn-lfs.huggingface.co/repos/6b/20/6b201da5f0f5c60524535ebb7deac2eef68605655d3bbacfee9cce0087f3b3f5/cc6cb27103417325ff94f52b7a5d2dde45a7515b25c255d8e396c90014281516?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27v1-5-pruned-emaonly.ckpt%3B+filename%3D%22v1-5-pruned-emaonly.ckpt%22%3B&Expires=1677445971&Policy=__&Signature=sq-ArxUmBD-ivE935Xavn2qnXfC0JHVHNffnJ4RSdEtRUCXEzyCj7NkzE%7EYpMgBKOtA9Tyza4I6oU-o6gj75oBjLPgF6SNAaQcYj8q6yH87uaePWBXvskIXNSZ2HOVjWLaLB%7EIkiVkEi%7ETkBqOnIbwLlBOfdKOPS4FLT-oEJNU6xgAlxKWIWj8ttJtCP8pK6Vmk6A2f0eMDuD6fZY8Ha-cDsdoVhl0It43szRSraK8JaA-bLTkOOoaWE62jYkbeNKWO40k9k6FttXfk-cdBS7JbWLPocs7colqVORnIPpb29nEnfQ86O9hwLj4AXH91gx%7EmK4beA3OtljGlytbckqQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 54.192.150.19, 54.192.150.21, 54.192.150.84, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|54.192.150.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265380512 (4.0G) [binary/octet-stream]
# Saving to: ‘./models/checkpoints/v1-5-pruned-emaonly.ckpt
?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27AbyssOrangeMix2_hard.safetensors%3B+filename%3D%22AbyssOrangeMix2_hard.safetensors%22%3B&Expires=1677448032&Policy=__&Signature=yA3G9FevmkWcBeNfffr5uJzMi7CdMLHow2qTOjDkCJzCycEtZ3T8NYq7FOmvOMp4PrE-VqjPOIb8o4G%7E54CDIZJuWSXNAkfnNUAmAkp55SV8A0Exlvpj5JleqoVc9TeQAo7ubwkFBPIJPupUH7HAm-0wCFMy9Tvf5W2s4EAEyod7NyBHqm10Q9wFJqil13eFLUpxW2EWtq87aUeT3UcnrmnULUVcvCan2VXGA8am2ISE4GEuYHVPhwTuV9j6A4OHoQEp9iwqTqZSiWETYk970kVxGrJv%7EBJdq-cd%7EXhHPXeFOXAd0lK8VH5uy8BPEBP5xIYZkSemkK2s2WIJdgmoaQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-02-23 21:54:09--  https://cdn-lfs.huggingface.co/repos/a3/2d/a32dc75b6b955f4b9a0498061b68d02fc24b9e596c8126c9817795c3f0356c18/0fc198c4908e98d7aae2a76bd78fa004e9c21cb0be7582e36008b4941169f18e?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27AbyssOrangeMix2_hard.safetensors%3B+filename%3D%22AbyssOrangeMix2_hard.safetensors%22%3B&Expires=1677448032&Policy=__&Signature=yA3G9FevmkWcBeNfffr5uJzMi7CdMLHow2qTOjDkCJzCycEtZ3T8NYq7FOmvOMp4PrE-VqjPOIb8o4G%7E54CDIZJuWSXNAkfnNUAmAkp55SV8A0Exlvpj5JleqoVc9TeQAo7ubwkFBPIJPupUH7HAm-0wCFMy9Tvf5W2s4EAEyod7NyBHqm10Q9wFJqil13eFLUpxW2EWtq87aUeT3UcnrmnULUVcvCan2VXGA8am2ISE4GEuYHVPhwTuV9j6A4OHoQEp9iwqTqZSiWETYk970kVxGrJv%7EBJdq-cd%7EXhHPXeFOXAd0lK8VH5uy8BPEBP5xIYZkSemkK2s2WIJdgmoaQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 54.192.150.19, 54.192.150.21, 54.192.150.84, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|54.192.150.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5570803627 (5.2G) [binary/octet-stream]
# Saving to: ‘./models/checkpoints/AbyssOrangeMix2_hard.safetensors’
#
# AbyssOrangeMix2_har 100%[===================>]   5.19G   231MB/s    in 22s
#
# 2023-02-23 21:54:31 (240 MB/s) - ‘./models/checkpoints/AbyssOrangeMix2_hard.safetensors’ saved [5570803627/5570803627]

# %% [markdown]
# Optional: Launch a http server to see the output pics (you can also download them by browsing to the output directory with colab):

# %%
from google.colab import output
output.serve_kernel_port_as_window(8000)
get_ipython().system_raw('cd output && python3 -m http.server 8000 &')

# %% [markdown]
# ### Run ComfyUI
# use the **fp16** model configs for more speed
#
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the second link not the first one.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --highvram
# Out:
# Set vram state to: HIGH VRAM
# 2023-02-23 21:54:37.729239: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-23 21:54:40.531196: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-23 21:54:40.531499: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-23 21:54:40.531523: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Using sub quadratic optimization for cross attention, if you have memory or speed issues try using: --use-split-cross-attention
# No module 'xformers'. Proceeding without it.
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
# to open it in a window you can open this link here:
