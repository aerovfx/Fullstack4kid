# %%
# !git clone https://github.com/sangyh/MockGPT4.git
# Out:
# Cloning into 'MockGPT4'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 17 (delta 0), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), 249.08 KiB | 2.44 MiB/s, done.

# %%
import os
path = os.path.join(os.getcwd(),'MockGPT4')
os.chdir(path)
# !ls

# %%
# !python3 -m venv mockgpt4env
# !source mockgpt4env/bin/activate
# !pip install -r requirements.txt

# %%
os.environ['OPENAI_API_KEY'] = '<YOUR-OPENAI-API-KEY>'

# %%
# !make start
# Out:
# INFO:     Will watch for changes in these directories: ['/content/MockGPT4']
# INFO:     Uvicorn running on http://127.0.0.1:9000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2734] using StatReload
# INFO:     Started server process [2736]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [2736]
# INFO:     Stopping reloader process [2734]
