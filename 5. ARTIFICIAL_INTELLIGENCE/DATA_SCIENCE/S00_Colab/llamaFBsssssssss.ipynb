# %%
# !git config -global user.email "vietchungvn@gmail.com"
# !git config –global user.name "vietchung"

# %%
# !git clone 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

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
pip install numpy

# %%
#@markdown # Dependencies

from IPython.utils import capture
import time
import os

print('[1;32mInstalling dependencies...')
with capture.capture_output() as cap:
    # %cd /content/
    # !pip install wget
    # !pip install -q --no-deps accelerate==0.12.0
    # !dpkg -i *.deb
    # !tar -C / --zstd -xf gcolab.tar.zst
    # !rm *.deb | rm *.zst | rm *.txt
    # !git clone --depth 1 --branch updt https://github.com/facebookresearch/llama.gitv
    # %env LD_PRELOAD=libtcmalloc.so
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

print('[1;32mDone, proceed')

# %%
# !pip install -r requirements.txt
