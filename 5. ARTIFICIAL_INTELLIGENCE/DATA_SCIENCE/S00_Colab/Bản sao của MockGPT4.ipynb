# %%
# !git clone https://github.com/aerovfx/MockGPT4.git
# Out:
# Cloning into 'MockGPT4'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import os
path = os.path.join(os.getcwd(),'MockGPT4')
os.chdir(path)
# !ls
# Out:
# assets	     main.py   query_data.py  requirements.txt	templates
# callback.py  Makefile  README.md      schemas.py

# %%
# !python3 -m venv mockgpt4env
# !source mockgpt4env/bin/activate
# !pip install -r requirements.txt
# Out:
# Error: Command '['/content/MockGPT4/mockgpt4env/bin/python3', '-Im', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# /bin/bash: mockgpt4env/bin/activate: No such file or directory
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 KB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.3/404.3 KB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 49.4 MB/s eta 0:00:00
# ...

# %%
os.environ['OPENAI_API_KEY'] = '<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>'

# %%
# !make start
# Out:
# uvicorn main:app --reload --port 9000
# INFO:     Will watch for changes in these directories: ['/content/MockGPT4']
# INFO:     Uvicorn running on http://127.0.0.1:9000 (Press CTRL+C to quit)
# INFO:     Started reloader process [3020] using StatReload
# INFO:     Started server process [3022]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
