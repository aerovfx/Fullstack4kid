# %% [markdown]
# <a href="https://colab.research.google.com/github/aerovfx/Aero-Fullstack4kid/blob/main/01dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: create dataframe with 2 col 2 row

import pandas as pd

data = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
# prompt: Using dataframe df: suggest a pilot

# Assuming you want to suggest a pilot based on some criteria,
# and you have no information about pilots in the dataframe,
# this code will randomly select a pilot from a list.

import random

def suggest_pilot():
    """Suggests a pilot from a predefined list."""
    pilots = ['Alice', 'Bob', 'Charlie', 'Dave'] # Replace with actual pilot data if available
    return random.choice(pilots)

suggested_pilot = suggest_pilot()
print(f"Suggested pilot: {suggested_pilot}")
# Out:
# Suggested pilot: Dave
